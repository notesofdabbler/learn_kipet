# %%
# https://github.com/kwmcbride/kipet_examples/blob/master/examples/example_2/Ex_2_estimation.py

# %%
import sys
import os
import kipet
import pandas as pd
import numpy as np
import altair as alt

# %%
def Lorentzian_parameters():
    params_d = dict()
    params_d['alphas'] = [0.0,20]
    params_d['betas'] = [1600.0,2200.0]
    params_d['gammas'] = [30000.0,1000.0]
    return {'D':params_d}

# %%
wl_span = np.arange(1610, 2601, 10)
S_parameters = Lorentzian_parameters()

# %%
S_parameters
# Out:
# {'D': {'alphas': [0.0, 20],
#   'betas': [1600.0, 2200.0],
#   'gammas': [30000.0, 1000.0]}}

# %%
from kipet.calculation_tools.prob_gen_tools import generate_absorbance_data
S_frame = generate_absorbance_data(wl_span,S_parameters)

# %%
df = S_frame.reset_index()

alt.Chart(df).mark_line().encode(
  alt.X('index:Q'),
  alt.Y('D:Q')
)
# Out:
# alt.Chart(...)

# %%
r1 = kipet.ReactionModel('reaction1')

# %%
k1 = r1.parameter('k1', value = 2, bounds = (0.01, 5.0))
k2 = r1.parameter('k2', value = 0.2, bounds = (0.01, 5.0))

# %%
A = r1.component('A', value = 1.0e-3)
B = r1.component('B', value = 0.0)
C = r1.component('C', value = 0.0)
D = r1.component('D', value = 1.0e-3, S = S_frame)

# %%
rA = r1.add_reaction('rA', k1 * A)
rB = r1.add_reaction('rB', k2 * B)

# %%
r1.add_ode('A', -rA)
r1.add_ode('B', rA - rB)
r1.add_ode('C', rB)
r1.add_ode('D', 0)
# Out:
# 0

# %%
r1.add_data(category = 'spectral', file = '/home/paperspace/learn_kipet/data_sets/Dij.txt')

# %%
 r1.spectra.savitzky_golay(window=11)
# Out:
# Applying the Savitzky-Golay filter
#           1610.0    1620.0    1630.0    1640.0    1650.0    1660.0    1670.0  \
# 0.0000  0.074030  0.076324  0.078295  0.080135  0.081958  0.084136  0.085914
# 0.0333  0.074780  0.076291  0.077859  0.079532  0.081877  0.083863  0.085702
# 0.0667  0.076256  0.076653  0.077825  0.078860  0.080333  0.081828  0.083561
# 0.1000  0.075783  0.076693  0.077462  0.078748  0.079840  0.081198  0.082083
# 0.1334  0.076389  0.077155  0.078513  0.079441  0.080110  0.080969  0.081674
# ...          ...       ...       ...       ...       ...       ...       ...
# 9.8353  0.087995  0.087640  0.086945  0.085566  0.083788  0.081823  0.079825
# 9.8686  0.087383  0.087142  0.086208  0.084534  0.082965  0.081180  0.079431
# 9.9020  0.087988  0.087409  0.086881  0.085555  0.083639  0.081564  0.079803
# 9.9353  0.087011  0.087088  0.086186  0.084398  0.082125  0.080655  0.078824
# 9.9687  0.087806  0.087396  0.086352  0.085200  0.083720  0.081960  0.081013
#
#           1680.0    1690.0    1700.0  ...    2510.0    2520.0    2530.0  \
# 0.0000  0.087293  0.087660  0.086500  ...  0.135019  0.131322  0.128058
# 0.0333  0.086211  0.085892  0.084587  ...  0.135105  0.132183  0.129170
# 0.0667  0.084664  0.084632  0.083289  ...  0.134636  0.131936  0.129011
# 0.1000  0.082634  0.082969  0.082087  ...  0.134524  0.131973  0.129310
# 0.1334  0.081837  0.081634  0.081137  ...  0.134675  0.132166  0.129701
# ...          ...       ...       ...  ...       ...       ...       ...
# 9.8353  0.078535  0.077523  0.076740  ...  0.131076  0.132066  0.133162
# 9.8686  0.078514  0.077984  0.076414  ...  0.131390  0.133133  0.133759
# 9.9020  0.078311  0.077312  0.076451  ...  0.129841  0.131041  0.132067
# 9.9353  0.077999  0.077530  0.076957  ...  0.132135  0.134175  0.135071
# 9.9687  0.079717  0.078544  0.077726  ...  0.131523  0.132297  0.132615
#
#           2540.0    2550.0    2560.0    2570.0    2580.0    2590.0    2600.0
# 0.0000  0.125851  0.125257  0.125919  0.126484  0.127740  0.129226  0.129647
# 0.0333  0.126687  0.124920  0.124667  0.125483  0.126952  0.127646  0.128757
# 0.0667  0.127259  0.126039  0.126001  0.126751  0.127957  0.128871  0.129517
# 0.1000  0.126965  0.126027  0.126137  0.127090  0.127845  0.129131  0.129071
# 0.1334  0.128271  0.127488  0.127364  0.127329  0.128479  0.129937  0.130156
# ...          ...       ...       ...       ...       ...       ...       ...
# 9.8353  0.134103  0.134625  0.134142  0.133074  0.131629  0.130613  0.130271
# 9.8686  0.133675  0.134069  0.133576  0.132666  0.131802  0.130457  0.129935
# 9.9020  0.132608  0.132868  0.132700  0.131847  0.130924  0.129825  0.129930
# 9.9353  0.135361  0.134550  0.133143  0.132438  0.132844  0.133148  0.134459
# 9.9687  0.132660  0.132915  0.132446  0.132161  0.131174  0.130826  0.130778
#
# [300 rows x 100 columns]

# %%
r1.settings.collocation.ncp = 3
r1.settings.collocation.nfe = 60
r1.settings.solver.linear_solver = 'ma27'

# %%
r1.run_opt()
# Out:
# ########################################
# # KIPET version 1.0.3
# # Date: 2021-07-07-16-47-37
# # File: <ipython-input-41-157868483296>
# # ReactionModel instance: reaction1
# ########################################
#
# # Simulator: Initializing with starting values
# # Simulator: Using the fe method
# # Simulator: Setting up simulation model
# # TemplateBuilder: Preparing model for simulator
# WARNING: More finite elements were found in ContinuousSet 'alltime' than the
#     number of finite elements specified in apply. The larger number of finite
#     elements will be used.
# # Simulator: Finished creating simulator
# # Simulator: Completed successfully
#
# # VarianceEsitmator: Creating instance
# # Warning: Template already populated
# ReactionModel: Generating base model (self._model)
# # TemplateBuilder: Preparing model for p_estimator
# # TemplateBuilder: Preparing model for v_estimator
# WARNING: More finite elements were found in ContinuousSet 'alltime' than the
#     number of finite elements specified in apply. The larger number of finite
#     elements will be used.
# # VarianceEstimator: Starting the variance estimator using originalchenetal method
# Solving Initialization Problem
#
# Ipopt 3.12: linear_solver=ma27
# nlp_scaling_method=gradient-based
# max_iter=15000
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:    39479
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:   274196
#
# Total number of variables............................:    11073
#                      variables with only lower bounds:      300
#                 variables with lower and upper bounds:        2
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:    10771
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.9448494e+02 1.00e+00 6.91e+01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.9933698e+02 5.60e-04 1.00e+02  -1.0 1.00e+00   2.0 8.52e-01 1.00e+00h  1
#    2  2.9922248e+02 7.05e-05 2.43e+01  -1.0 2.83e-01   1.5 1.00e+00 1.00e+00f  1
#    3  2.9850222e+02 1.35e-06 1.43e+00  -1.0 1.29e-01   1.0 1.00e+00 1.00e+00f  1
#    4  2.9802893e+02 9.06e-05 8.36e-02  -1.0 2.61e-01    -  9.43e-01 1.00e+00f  1
#    5  2.9795810e+02 1.49e-06 7.13e-02  -2.5 1.92e-02   0.6 1.00e+00 1.00e+00h  1
#    6  2.9772095e+02 4.08e-06 8.55e-02  -2.5 7.59e-02   0.1 1.00e+00 1.00e+00f  1
#    7  2.9691423e+02 9.07e-05 5.21e-01  -2.5 3.90e-01  -0.4 1.00e+00 1.00e+00f  1
#    8  2.9465353e+02 1.77e-04 1.44e+00  -2.5 7.77e-01  -0.9 1.00e+00 1.00e+00f  1
#    9  2.8707169e+02 5.36e-04 6.12e+00  -2.5 1.83e+00  -1.3 9.58e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.8340446e+02 5.47e-04 6.57e+00  -2.5 1.26e+02    -  2.20e-02 7.51e-03f  1
#   11  2.7433863e+02 5.56e-04 8.66e+00  -2.5 1.31e+02    -  3.71e-02 1.73e-02f  1
#   12  1.9320410e+02 4.62e-04 5.52e+01  -2.5 1.23e+02    -  2.17e-01 1.70e-01f  1
#   13  1.5575194e+02 4.11e-04 6.41e+01  -2.5 1.05e+02    -  2.60e-01 1.10e-01f  1
#   14  7.8133009e+00 6.86e-07 9.99e+02  -2.5 9.39e+01    -  5.81e-01 1.00e+00f  1
#   15  4.2385362e+00 3.18e-10 3.54e+02  -2.5 2.14e+02    -  8.75e-02 1.00e+00f  1
#   16  1.3555735e+00 1.12e-09 5.50e+02  -2.5 9.82e+01    -  3.12e-01 1.00e+00f  1
#   17  1.8796702e-01 3.01e-09 2.57e+02  -2.5 5.93e+01    -  5.11e-01 1.00e+00f  1
#   18  7.9502640e-02 1.22e-08 6.15e+01  -2.5 4.72e+01    -  8.74e-01 1.00e+00f  1
#   19  7.3845622e-02 3.33e-04 3.66e+01  -2.5 3.28e+01    -  9.70e-03 3.29e-01f  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  7.1419790e-02 4.57e-04 3.10e+01  -2.5 8.12e+00  -1.8 1.00e+00 1.53e-01h  2
#   21  6.9596564e-02 4.17e-06 1.47e-01  -2.5 7.42e-02  -1.4 1.00e+00 1.00e+00h  1
#   22  6.9283829e-02 1.54e-05 2.62e-02  -2.5 4.51e-01  -1.9 1.00e+00 1.00e+00h  1
#   23  6.8828133e-02 1.30e-06 3.01e-03  -3.8 7.80e-02  -2.3 9.99e-01 1.00e+00h  1
#   24  6.8071855e-02 1.11e-06 2.86e-03  -3.8 1.35e-01  -2.8 1.00e+00 1.00e+00h  1
#   25  6.6889943e-02 5.03e-06 2.62e-02  -3.8 2.47e-01  -3.3 1.00e+00 1.00e+00h  1
#   26  6.4308787e-02 1.87e-05 2.09e-01  -3.8 6.04e-01  -3.8 1.00e+00 1.00e+00h  1
#   27  5.3074796e-02 2.56e-04 2.99e+00  -3.8 4.02e+00  -4.3 6.30e-01 1.00e+00h  1
#   28  3.4829119e-02 3.18e-04 5.38e+00  -3.8 2.68e+01    -  1.00e+00 1.84e-01h  1
#   29  3.2828997e-02 5.31e-04 1.89e+00  -3.8 1.04e+01    -  2.69e-02 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  2.3912594e-02 2.82e-04 7.95e-01  -3.8 1.22e+01    -  3.14e-02 5.00e-01h  2
#   31  1.5279239e-02 1.50e-04 8.46e-01  -3.8 1.60e+00  -4.7 1.00e+00 1.00e+00h  1
#   32  1.2409838e-02 2.23e-05 1.36e+00  -3.8 5.52e+00    -  1.00e+00 1.00e+00h  1
#   33  1.2335885e-02 3.74e-07 7.32e-03  -3.8 1.49e-01    -  1.00e+00 1.00e+00h  1
#   34  1.2335168e-02 3.61e-10 2.59e-05  -3.8 2.40e-02    -  1.00e+00 1.00e+00h  1
#   35  1.2323734e-02 6.63e-08 6.53e-03  -5.7 2.07e-01    -  1.00e+00 1.00e+00h  1
#   36  1.2323705e-02 4.94e-10 1.76e-05  -5.7 1.95e-02    -  1.00e+00 1.00e+00h  1
#   37  1.2323703e-02 1.44e-11 1.27e-06  -8.6 3.21e-03    -  1.00e+00 1.00e+00h  1
#   38  1.2323703e-02 8.53e-14 8.68e-13  -8.6 4.05e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 38
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.2323702635047850e-02    1.2323702635047850e-02
# Dual infeasibility......:   8.6775031604702235e-13    8.6775031604702235e-13
# Constraint violation....:   3.7697013850273456e-14    8.5265128291212010e-14
# Complementarity.........:   2.5059039141040852e-09    2.5059039141040852e-09
# Overall NLP error.......:   2.5059039141040852e-09    2.5059039141040852e-09
#
#
# Number of objective function evaluations             = 45
# Number of objective gradient evaluations             = 39
# Number of equality constraint evaluations            = 45
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 39
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 38
# Total CPU secs in IPOPT (w/o function evaluations)   =      5.536
# Total CPU secs in NLP function evaluations           =      5.704
#
# EXIT: Optimal Solution Found.
#        Iter            |Zi-Zi+1|
#           1 1.870129700352733e-08
# Iterative optimization converged. Estimating variances now
# # VarianceEstimator: Complete
#
# # VarianceEstimator: All variances provided / concentration problem
#
# # ParameterEstimator: Creating instance
#
# # Warning: Template already populated
# # TemplateBuilder: Preparing model for p_estimator
# WARNING: More finite elements were found in ContinuousSet 'alltime' than the
#     number of finite elements specified in apply. The larger number of finite
#     elements will be used.
# # ParameterEstimator: The variances being used are:
#  {'A': 1.577733069863246e-10, 'B': 1.7751808754277727e-10, 'C': 6.983171309908663e-11, 'device': 1.8197001979129254e-06}
# # ParameterEstimator: Solving the parameter fitting problem...
#
#
# # Parameter Values
#              k1 = 2.5945e-01
#              k2 = 1.3250e+00
#
# # ParameterEstimator: Parameter fitting complete
# # KIPET procedure for reaction1 finished
# RESULTS
# Z:
#                   A             B             C      D
# 0.000000  0.001000 -8.443497e-41 -1.030926e-38  0.001
# 0.005163  0.000999  1.334106e-06  4.570589e-09  0.001
# 0.021477  0.000994  5.478199e-06  7.838629e-08  0.001
# 0.033300  0.000991  8.415073e-06  1.872808e-07  0.001
# 0.038479  0.000990  9.684116e-06  2.493826e-07  0.001
# ...            ...           ...           ...    ...
# 9.923477  0.000076  1.854964e-05  9.052669e-04  0.001
# 9.935300  0.000076  1.849283e-05  9.055571e-04  0.001
# 9.940479  0.000076  1.846800e-05  9.056839e-04  0.001
# 9.956841  0.000076  1.838977e-05  9.060834e-04  0.001
# 9.968700  0.000075  1.833329e-05  9.063719e-04  0.001
#
# [898 rows x 4 columns]
#
# C:
#                 A         B         C      D
# 0.0000  0.001037  0.000000  0.000009  0.001
# 0.0333  0.001022  0.000008  0.000013  0.001
# 0.0667  0.001013  0.000019  0.000010  0.001
# 0.1000  0.000996  0.000029  0.000009  0.001
# 0.1334  0.000983  0.000039  0.000010  0.001
# ...          ...       ...       ...    ...
# 9.8353  0.000075  0.000023  0.000908  0.001
# 9.8686  0.000077  0.000023  0.000904  0.001
# 9.9020  0.000076  0.000022  0.000905  0.001
# 9.9353  0.000073  0.000025  0.000907  0.001
# 9.9687  0.000077  0.000019  0.000909  0.001
#
# [300 rows x 4 columns]
#
# S:
#                   A           B           C              D
# 1610.0   71.397316  117.442880   87.410008  1.327764e-150
# 1620.0   72.681415  108.996118   87.223256  1.600908e-145
# 1630.0   74.308097   93.872699   86.555845  1.580348e-140
# 1640.0   76.140947   73.966746   85.399077  1.277263e-135
# 1650.0   78.210407   50.847934   83.959479  8.451800e-131
# ...            ...         ...         ...            ...
# 2560.0  119.821759  207.333111  131.436131   1.038640e-55
# 2570.0  120.720987  199.026715  130.732501   7.016418e-59
# 2580.0  122.042233  189.175495  130.024286   3.880671e-62
# 2590.0  123.250040  181.151696  129.417385   1.757273e-65
# 2600.0  123.773838  178.563909  129.419307   6.514977e-69
#
# [100 rows x 4 columns]
#
# X:
#              V
# 0.000000  1.0
# 0.005163  1.0
# 0.021477  1.0
# 0.033300  1.0
# 0.038479  1.0
# ...       ...
# 9.923477  1.0
# 9.935300  1.0
# 9.940479  1.0
# 9.956841  1.0
# 9.968700  1.0
#
# [898 rows x 1 columns]
#
# dZdt:
#                   A         B         C    D
# 0.000000  0.000000  0.000000  0.000000  0.0
# 0.005163 -0.000259  0.000257  0.000002  0.0
# 0.021477 -0.000258  0.000251  0.000007  0.0
# 0.033300 -0.000257  0.000246  0.000011  0.0
# 0.038479 -0.000257  0.000244  0.000013  0.0
# ...            ...       ...       ...  ...
# 9.923477 -0.000020 -0.000005  0.000025  0.0
# 9.935300 -0.000020 -0.000005  0.000025  0.0
# 9.940479 -0.000020 -0.000005  0.000024  0.0
# 9.956841 -0.000020 -0.000005  0.000024  0.0
# 9.968700 -0.000020 -0.000005  0.000024  0.0
#
# [898 rows x 4 columns]
#
# dXdt:
#              V
# 0.000000  0.0
# 0.005163  0.0
# 0.021477  0.0
# 0.033300  0.0
# 0.038479  0.0
# ...       ...
# 9.923477  0.0
# 9.935300  0.0
# 9.940479  0.0
# 9.956841  0.0
# 9.968700  0.0
#
# [898 rows x 1 columns]
#
# P:
#  {'k1': 0.25944648417181654, 'k2': 1.3249671332719186}
#
# Y:
#                  rA            rB
# 0.000000  0.000259 -1.134042e-40
# 0.005163  0.000259  1.767647e-06
# 0.021477  0.000258  7.258434e-06
# 0.033300  0.000257  1.114970e-05
# 0.038479  0.000257  1.283113e-05
# ...            ...           ...
# 9.923477  0.000020  2.457766e-05
# 9.935300  0.000020  2.450239e-05
# 9.940479  0.000020  2.446949e-05
# 9.956841  0.000020  2.436585e-05
# 9.968700  0.000020  2.429100e-05
#
# [898 rows x 2 columns]

# %%
r1.report()

# %%
Zdf = r1.results.Z.reset_index()
Cdf = r1.results.C.reset_index()
Sdf = r1.results.S.reset_index()

# %%
Zdfg = pd.melt(Zdf, id_vars = 'index', value_vars = ['A', 'B', 'C', 'D'])
Cdfg = pd.melt(Cdf, id_vars = 'index', value_vars = ['A', 'B', 'C', 'D'])
Sdfg = pd.melt(Sdf, id_vars = 'index', value_vars = ['A', 'B', 'C', 'D'])

# %%
alt.Chart(Zdfg).mark_line().encode(
  alt.X('index:Q'),
  alt.Y('value:Q'),
  alt.Color('variable:N')
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(Cdfg).mark_line().encode(
  alt.X('index:Q'),
  alt.Y('value:Q'),
  alt.Color('variable:N')
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(Sdfg).mark_line().encode(
  alt.X('index:Q'),
  alt.Y('value:Q'),
  alt.Color('variable:N')
)
# Out:
# alt.Chart(...)
